# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import cufflinks as cs
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv('/content/drive/MyDrive/Archive/stroke_data.csv')

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  58.0             1              0          Yes        Private
# 1  Female  70.0             0              0          Yes        Private
# 2  Female  52.0             0              0          Yes        Private
# 3  Female  75.0             0              1          Yes  Self-employed
# 4  Female  32.0             0              0          Yes        Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban              87.96  39.2     never smoked       0
# 1          Rural              69.04  35.9  formerly smoked       0
# 2          Urban              77.59  17.7  formerly smoked       0
# 3          Rural             243.53  27.0     never smoked       0
# 4          Rural              77.67  32.3           smokes       0

# %%
df.shape
# Out:
# (29065, 11)

# %%
df.isnull().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
df.describe()
# Out:
#                 age  hypertension  heart_disease  avg_glucose_level  \
# count  29065.000000  29065.000000   29065.000000       29065.000000
# mean      47.676174      0.111509       0.052159         106.405639
# std       18.732941      0.314766       0.222351          45.272453
# min       10.000000      0.000000       0.000000          55.010000
# 25%       32.000000      0.000000       0.000000          77.630000
# 50%       48.000000      0.000000       0.000000          92.130000
# 75%       62.000000      0.000000       0.000000         113.910000
# max       82.000000      1.000000       1.000000         291.050000
#
#                 bmi        stroke
# count  29065.000000  29065.000000
# mean      30.054684      0.018854
# std        7.193951      0.136013
# min       10.100000      0.000000
# 25%       25.000000      0.000000
# 50%       28.900000      0.000000
# 75%       33.900000      0.000000
# max       92.000000      1.000000

# %%
df.nunique()
# Out:
# gender                   2
# age                     73
# hypertension             2
# heart_disease            2
# ever_married             2
# work_type                5
# Residence_type           2
# avg_glucose_level    11041
# bmi                    516
# smoking_status           3
# stroke                   2
# dtype: int64

# %%
plt.style.use('dark_background')

# %%
plt.figure(figsize=(6,4),dpi=100)
sns.distplot(df['age'],hist=True)
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
plt.figure(figsize=(10,6),dpi=100)
sns.lineplot(x='age',y='avg_glucose_level',data=df,hue='gender')
# Out:
# <Axes: xlabel='age', ylabel='avg_glucose_level'>

# %%
bins=[0,20,40,60,80,100]
df['Age-Group']=pd.cut(df['age'],bins=bins,labels=['Below 20','20-40','40-60','60-80','80-100'],include_lowest=True)
df
# Out:
#        gender   age  hypertension  heart_disease ever_married      work_type  \
# 0        Male  58.0             1              0          Yes        Private
# 1      Female  70.0             0              0          Yes        Private
# 2      Female  52.0             0              0          Yes        Private
# 3      Female  75.0             0              1          Yes  Self-employed
# 4      Female  32.0             0              0          Yes        Private
# ...       ...   ...           ...            ...          ...            ...
# 29060  Female  10.0             0              0           No       children
# 29061  Female  56.0             0              0          Yes       Govt_job
# 29062  Female  82.0             1              0          Yes        Private
# 29063    Male  40.0             0              0          Yes        Private
# 29064  Female  82.0             0              0          Yes        Private
#
#       Residence_type  avg_glucose_level   bmi   smoking_status  stroke  \
# 0              Urban              87.96  39.2     never smoked       0
# 1              Rural              69.04  35.9  formerly smoked       0
# 2              Urban              77.59  17.7  formerly smoked       0
# 3              Rural             243.53  27.0     never smoked       0
# 4              Rural              77.67  32.3           smokes       0
# ...              ...                ...   ...              ...     ...
# 29060          Urban              58.64  20.4     never smoked       0
# 29061          Urban             213.61  55.4  formerly smoked       0
# 29062          Urban              91.94  28.9  formerly smoked       0
# 29063          Urban              99.16  33.2     never smoked       0
# 29064          Urban              79.48  20.6     never smoked       0
#
#       Age-Group
# 0         40-60
# 1         60-80
# 2         40-60
# 3         60-80
# 4         20-40
# ...         ...
# 29060  Below 20
# 29061     40-60
# 29062    80-100
# 29063     20-40
# 29064    80-100
#
# [29065 rows x 12 columns]

# %%
plt.figure(figsize=(10,6),dpi=100)
sns.boxplot(x='Age-Group',y='avg_glucose_level',data=df)
# Out:
# <Axes: xlabel='Age-Group', ylabel='avg_glucose_level'>

# %%
plt.figure(figsize=(10,6))
df['smoking_status'].value_counts().plot(kind='bar',color='red')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,6))
df['work_type'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,6),dpi=100)
sns.lineplot(x='age',y='bmi',data=df,hue='gender')
# Out:
# <Axes: xlabel='age', ylabel='bmi'>

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='avg_glucose_level',y='bmi',data=df,palette='cool',hue='gender')
# Out:
# <Axes: xlabel='avg_glucose_level', ylabel='bmi'>

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29065 entries, 0 to 29064
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             29065 non-null  object
#  1   age                29065 non-null  float64
#  2   hypertension       29065 non-null  int64
#  3   heart_disease      29065 non-null  int64
#  4   ever_married       29065 non-null  object
#  5   work_type          29065 non-null  object
#  6   Residence_type     29065 non-null  object
#  7   avg_glucose_level  29065 non-null  float64
#  8   bmi                29065 non-null  float64
#  9   smoking_status     29065 non-null  object
#  10  stroke             29065 non-null  int64
#  11  Age-Group          29065 non-null  category
# dtypes: category(1), float64(3), int64(3), object(5)
# memory usage: 2.5+ MB

# %%
df.nunique()
# Out:
# gender                   2
# age                     73
# hypertension             2
# heart_disease            2
# ever_married             2
# work_type                5
# Residence_type           2
# avg_glucose_level    11041
# bmi                    516
# smoking_status           3
# stroke                   2
# Age-Group                5
# dtype: int64

# %%
df.isna().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# Age-Group            0
# dtype: int64

# %%
df['Residence_type'].unique()
# Out:
# array(['Urban', 'Rural'], dtype=object)

# %%
df['Residence_type']=df['Residence_type'].map({'Urban':1,'Rural':0})
df
# Out:
#        gender   age  hypertension  heart_disease ever_married      work_type  \
# 0        Male  58.0             1              0          Yes        Private
# 1      Female  70.0             0              0          Yes        Private
# 2      Female  52.0             0              0          Yes        Private
# 3      Female  75.0             0              1          Yes  Self-employed
# 4      Female  32.0             0              0          Yes        Private
# ...       ...   ...           ...            ...          ...            ...
# 29060  Female  10.0             0              0           No       children
# 29061  Female  56.0             0              0          Yes       Govt_job
# 29062  Female  82.0             1              0          Yes        Private
# 29063    Male  40.0             0              0          Yes        Private
# 29064  Female  82.0             0              0          Yes        Private
#
#        Residence_type  avg_glucose_level   bmi   smoking_status  stroke  \
# 0                   1              87.96  39.2     never smoked       0
# 1                   0              69.04  35.9  formerly smoked       0
# 2                   1              77.59  17.7  formerly smoked       0
# 3                   0             243.53  27.0     never smoked       0
# 4                   0              77.67  32.3           smokes       0
# ...               ...                ...   ...              ...     ...
# 29060               1              58.64  20.4     never smoked       0
# 29061               1             213.61  55.4  formerly smoked       0
# 29062               1              91.94  28.9  formerly smoked       0
# 29063               1              99.16  33.2     never smoked       0
# 29064               1              79.48  20.6     never smoked       0
#
#       Age-Group
# 0         40-60
# 1         60-80
# 2         40-60
# 3         60-80
# 4         20-40
# ...         ...
# 29060  Below 20
# 29061     40-60
# 29062    80-100
# 29063     20-40
# 29064    80-100
#
# [29065 rows x 12 columns]

# %%
df['gender']=df['gender'].map({'Male':0,'Female':1})
df
# Out:
#        gender   age  hypertension  heart_disease ever_married      work_type  \
# 0           0  58.0             1              0          Yes        Private
# 1           1  70.0             0              0          Yes        Private
# 2           1  52.0             0              0          Yes        Private
# 3           1  75.0             0              1          Yes  Self-employed
# 4           1  32.0             0              0          Yes        Private
# ...       ...   ...           ...            ...          ...            ...
# 29060       1  10.0             0              0           No       children
# 29061       1  56.0             0              0          Yes       Govt_job
# 29062       1  82.0             1              0          Yes        Private
# 29063       0  40.0             0              0          Yes        Private
# 29064       1  82.0             0              0          Yes        Private
#
#        Residence_type  avg_glucose_level   bmi   smoking_status  stroke  \
# 0                   1              87.96  39.2     never smoked       0
# 1                   0              69.04  35.9  formerly smoked       0
# 2                   1              77.59  17.7  formerly smoked       0
# 3                   0             243.53  27.0     never smoked       0
# 4                   0              77.67  32.3           smokes       0
# ...               ...                ...   ...              ...     ...
# 29060               1              58.64  20.4     never smoked       0
# 29061               1             213.61  55.4  formerly smoked       0
# 29062               1              91.94  28.9  formerly smoked       0
# 29063               1              99.16  33.2     never smoked       0
# 29064               1              79.48  20.6     never smoked       0
#
#       Age-Group
# 0         40-60
# 1         60-80
# 2         40-60
# 3         60-80
# 4         20-40
# ...         ...
# 29060  Below 20
# 29061     40-60
# 29062    80-100
# 29063     20-40
# 29064    80-100
#
# [29065 rows x 12 columns]

# %%
df['ever_married']=df['ever_married'].map({'Yes':1,'No':0})
df
# Out:
#        gender   age  hypertension  heart_disease  ever_married      work_type  \
# 0           0  58.0             1              0             1        Private
# 1           1  70.0             0              0             1        Private
# 2           1  52.0             0              0             1        Private
# 3           1  75.0             0              1             1  Self-employed
# 4           1  32.0             0              0             1        Private
# ...       ...   ...           ...            ...           ...            ...
# 29060       1  10.0             0              0             0       children
# 29061       1  56.0             0              0             1       Govt_job
# 29062       1  82.0             1              0             1        Private
# 29063       0  40.0             0              0             1        Private
# 29064       1  82.0             0              0             1        Private
#
#        Residence_type  avg_glucose_level   bmi   smoking_status  stroke  \
# 0                   1              87.96  39.2     never smoked       0
# 1                   0              69.04  35.9  formerly smoked       0
# 2                   1              77.59  17.7  formerly smoked       0
# 3                   0             243.53  27.0     never smoked       0
# 4                   0              77.67  32.3           smokes       0
# ...               ...                ...   ...              ...     ...
# 29060               1              58.64  20.4     never smoked       0
# 29061               1             213.61  55.4  formerly smoked       0
# 29062               1              91.94  28.9  formerly smoked       0
# 29063               1              99.16  33.2     never smoked       0
# 29064               1              79.48  20.6     never smoked       0
#
#       Age-Group
# 0         40-60
# 1         60-80
# 2         40-60
# 3         60-80
# 4         20-40
# ...         ...
# 29060  Below 20
# 29061     40-60
# 29062    80-100
# 29063     20-40
# 29064    80-100
#
# [29065 rows x 12 columns]

# %%
work_type=pd.get_dummies(df['work_type'])
df=pd.concat([df,work_type],axis=1)
df=df.drop('work_type',axis=1)

# %%
df
# Out:
#        gender   age  hypertension  heart_disease  ever_married  \
# 0           0  58.0             1              0             1
# 1           1  70.0             0              0             1
# 2           1  52.0             0              0             1
# 3           1  75.0             0              1             1
# 4           1  32.0             0              0             1
# ...       ...   ...           ...            ...           ...
# 29060       1  10.0             0              0             0
# 29061       1  56.0             0              0             1
# 29062       1  82.0             1              0             1
# 29063       0  40.0             0              0             1
# 29064       1  82.0             0              0             1
#
#        Residence_type  avg_glucose_level   bmi   smoking_status  stroke  \
# 0                   1              87.96  39.2     never smoked       0
# 1                   0              69.04  35.9  formerly smoked       0
# 2                   1              77.59  17.7  formerly smoked       0
# 3                   0             243.53  27.0     never smoked       0
# 4                   0              77.67  32.3           smokes       0
# ...               ...                ...   ...              ...     ...
# 29060               1              58.64  20.4     never smoked       0
# 29061               1             213.61  55.4  formerly smoked       0
# 29062               1              91.94  28.9  formerly smoked       0
# 29063               1              99.16  33.2     never smoked       0
# 29064               1              79.48  20.6     never smoked       0
#
#       Age-Group  Govt_job  Never_worked  Private  Self-employed  children
# 0         40-60         0             0        1              0         0
# 1         60-80         0             0        1              0         0
# 2         40-60         0             0        1              0         0
# 3         60-80         0             0        0              1         0
# 4         20-40         0             0        1              0         0
# ...         ...       ...           ...      ...            ...       ...
# 29060  Below 20         0             0        0              0         1
# 29061     40-60         1             0        0              0         0
# 29062    80-100         0             0        1              0         0
# 29063     20-40         0             0        1              0         0
# 29064    80-100         0             0        1              0         0
#
# [29065 rows x 16 columns]

# %%
smoker=pd.get_dummies(df['smoking_status'])
df=pd.concat([df,smoker],axis=1)
df=df.drop('smoking_status',axis=1)

# %%
df
# Out:
#        gender   age  hypertension  heart_disease  ever_married  \
# 0           0  58.0             1              0             1
# 1           1  70.0             0              0             1
# 2           1  52.0             0              0             1
# 3           1  75.0             0              1             1
# 4           1  32.0             0              0             1
# ...       ...   ...           ...            ...           ...
# 29060       1  10.0             0              0             0
# 29061       1  56.0             0              0             1
# 29062       1  82.0             1              0             1
# 29063       0  40.0             0              0             1
# 29064       1  82.0             0              0             1
#
#        Residence_type  avg_glucose_level   bmi  stroke Age-Group  Govt_job  \
# 0                   1              87.96  39.2       0     40-60         0
# 1                   0              69.04  35.9       0     60-80         0
# 2                   1              77.59  17.7       0     40-60         0
# 3                   0             243.53  27.0       0     60-80         0
# 4                   0              77.67  32.3       0     20-40         0
# ...               ...                ...   ...     ...       ...       ...
# 29060               1              58.64  20.4       0  Below 20         0
# 29061               1             213.61  55.4       0     40-60         1
# 29062               1              91.94  28.9       0    80-100         0
# 29063               1              99.16  33.2       0     20-40         0
# 29064               1              79.48  20.6       0    80-100         0
#
#        Never_worked  Private  Self-employed  children  formerly smoked  \
# 0                 0        1              0         0                0
# 1                 0        1              0         0                1
# 2                 0        1              0         0                1
# 3                 0        0              1         0                0
# 4                 0        1              0         0                0
# ...             ...      ...            ...       ...              ...
# 29060             0        0              0         1                0
# 29061             0        0              0         0                1
# 29062             0        1              0         0                1
# 29063             0        1              0         0                0
# 29064             0        1              0         0                0
#
#        never smoked  smokes
# 0                 1       0
# 1                 0       0
# 2                 0       0
# 3                 1       0
# 4                 0       1
# ...             ...     ...
# 29060             1       0
# 29061             0       0
# 29062             0       0
# 29063             1       0
# 29064             1       0
#
# [29065 rows x 18 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29065 entries, 0 to 29064
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             29065 non-null  int64
#  1   age                29065 non-null  float64
#  2   hypertension       29065 non-null  int64
#  3   heart_disease      29065 non-null  int64
#  4   ever_married       29065 non-null  int64
#  5   Residence_type     29065 non-null  int64
#  6   avg_glucose_level  29065 non-null  float64
#  7   bmi                29065 non-null  float64
#  8   stroke             29065 non-null  int64
#  9   Age-Group          29065 non-null  category
#  10  Govt_job           29065 non-null  uint8
#  11  Never_worked       29065 non-null  uint8
#  12  Private            29065 non-null  uint8
#  13  Self-employed      29065 non-null  uint8
#  14  children           29065 non-null  uint8
#  15  formerly smoked    29065 non-null  uint8
#  16  never smoked       29065 non-null  uint8
#  17  smokes             29065 non-null  uint8
# dtypes: category(1), float64(3), int64(6), uint8(8)
# memory usage: 2.2 MB

# %%
df.drop('Age-Group',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29065 entries, 0 to 29064
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             29065 non-null  int64
#  1   age                29065 non-null  float64
#  2   hypertension       29065 non-null  int64
#  3   heart_disease      29065 non-null  int64
#  4   ever_married       29065 non-null  int64
#  5   Residence_type     29065 non-null  int64
#  6   avg_glucose_level  29065 non-null  float64
#  7   bmi                29065 non-null  float64
#  8   stroke             29065 non-null  int64
#  9   Govt_job           29065 non-null  uint8
#  10  Never_worked       29065 non-null  uint8
#  11  Private            29065 non-null  uint8
#  12  Self-employed      29065 non-null  uint8
#  13  children           29065 non-null  uint8
#  14  formerly smoked    29065 non-null  uint8
#  15  never smoked       29065 non-null  uint8
#  16  smokes             29065 non-null  uint8
# dtypes: float64(3), int64(6), uint8(8)
# memory usage: 2.2 MB

# %%
x=df.drop('stroke',axis=1)
y=df['stroke']

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score

# %%
from sklearn.preprocessing import StandardScaler

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=101)
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(x_train)
X_test=scaler.transform(x_test)

# %%
y=y.values

# %%
import warnings
warnings.simplefilter(action='ignore')

# %%
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import StratifiedKFold, cross_val_score

# %%
from sklearn.metrics import classification_report, confusion_matrix,r2_score,accuracy_score,roc_auc_score,RocCurveDisplay

# %%
def classify(classification,x_train,y_train,x_test,y_test):
    clf=classification.fit(x_train,y_train)
    pred=clf.predict(x_test)
    print('='*35)
    print(i)
    print('-'*35)
    print('Confusion Matrix=','\n',confusion_matrix(y_test,pred>0.5))
    print('-'*35)
    acc=accuracy_score(y_test,pred>0.5)
    print('Accuracy score=',acc)
    print('-'*35)
    kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    cv_report=cross_val_score(i,x,y,cv=kfold,scoring='accuracy')
    print('Cross-Validation Score=',cv_report.mean())
    print('-'*35)
    print('Roc-Auc-Score=',roc_auc_score(y_test,pred))
    print('='*35)

# %%
models = [
    LinearRegression(),
    LogisticRegression(),
    DecisionTreeClassifier(),
    RandomForestClassifier(),
    GaussianNB(),
    SVC(),
    KNeighborsClassifier()
]

# %%
df['stroke'].value_counts()
# Out:
# 0    28517
# 1      548
# Name: stroke, dtype: int64

# %%
pip install imblearn
# Out:
# Requirement already satisfied: imblearn in /usr/local/lib/python3.10/dist-packages (0.0)
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.10/dist-packages (from imblearn) (0.10.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn->imblearn) (1.22.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn->imblearn) (1.10.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn->imblearn) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn->imblearn) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn->imblearn) (3.1.0)

# %%
from collections import Counter

# %%
from imblearn.over_sampling import RandomOverSampler
ros=RandomOverSampler(random_state=0)
x_resampled,y_resampled=ros.fit_resample(x,y)

# %%
print(sorted(Counter(y_resampled).items()),y_resampled.shape)
# Out:
# [(0, 28517), (1, 28517)] (57034,)

# %%
for i in models:
  classify(i,x_resampled,y_resampled,x_test,y_test)
# Out:
# ===================================
# LinearRegression()
# -----------------------------------
# Confusion Matrix=
#  [[6175 2395]
#  [  29  121]]
# -----------------------------------
# Accuracy score= 0.7220183486238532
# -----------------------------------
# Cross-Validation Score= nan
# -----------------------------------
# Roc-Auc-Score= 0.8371816413846751
# ===================================
# ===================================
# LogisticRegression()
# -----------------------------------
# Confusion Matrix=
#  [[6395 2175]
#  [  34  116]]
# -----------------------------------
# Accuracy score= 0.7466743119266055
# -----------------------------------
# Cross-Validation Score= 0.981145707896095
# -----------------------------------
# Roc-Auc-Score= 0.7597705173084404
# ===================================
# ===================================
# DecisionTreeClassifier()
# -----------------------------------
# Confusion Matrix=
#  [[8570    0]
#  [   0  150]]
# -----------------------------------
# Accuracy score= 1.0
# -----------------------------------
# Cross-Validation Score= 0.9612248408739033
# -----------------------------------
# Roc-Auc-Score= 1.0
# ===================================
# ===================================
# RandomForestClassifier()
# -----------------------------------
# Confusion Matrix=
#  [[8570    0]
#  [   0  150]]
# -----------------------------------
# Accuracy score= 1.0
# -----------------------------------
# Cross-Validation Score= 0.9810768966110442
# -----------------------------------
# Roc-Auc-Score= 1.0
# ===================================
# ===================================
# GaussianNB()
# -----------------------------------
# Confusion Matrix=
#  [[1701 6869]
#  [   0  150]]
# -----------------------------------
# Accuracy score= 0.21227064220183486
# -----------------------------------
# Cross-Validation Score= 0.36769310166867364
# -----------------------------------
# Roc-Auc-Score= 0.5992415402567095
# ===================================
# ===================================
# SVC()
# -----------------------------------
# Confusion Matrix=
#  [[5914 2656]
#  [  29  121]]
# -----------------------------------
# Accuracy score= 0.6920871559633027
# -----------------------------------
# Cross-Validation Score= 0.981145707896095
# -----------------------------------
# Roc-Auc-Score= 0.7483741734733567
# ===================================
# ===================================
# KNeighborsClassifier()
# -----------------------------------
# Confusion Matrix=
#  [[8285  285]
#  [   0  150]]
# -----------------------------------
# Accuracy score= 0.9673165137614679
# -----------------------------------
# Cross-Validation Score= 0.9806984345432651
# -----------------------------------
# Roc-Auc-Score= 0.9833722287047841
# ===================================

# %%
x=df.drop('stroke',axis=1)
y=df['stroke']

# %%
fold = 0
aucs = []
for train_idx,val_idx in kfold.split(x,y):
  X_tr=x.iloc[train_idx]
  y_tr=y.iloc[train_idx]

  X_val=x.iloc[val_idx]
  y_val=y.iloc[val_idx]

  clf = RandomForestClassifier()
  clf.fit(X_tr, y_tr)
  pred = clf.predict(X_val)
  pred_prob = clf.predict_proba(X_val)[:, 1]
  acc_score = accuracy_score(y_val, pred)
  auc_score = roc_auc_score(y_val, pred_prob)
  print(f"======= Fold {fold} ========")
  print(
        f"Our accuracy on the validation set is {acc_score:0.4f} and AUC is {auc_score:0.4f}"
  )
  fold += 1
  aucs.append(auc_score)
oof_auc = np.mean(aucs)
print(f'Our out of fold AUC score is {oof_auc:0.4f}')
# Out:
# ======= Fold 0 ========
# Our accuracy on the validation set is 0.9812 and AUC is 0.7204
# ======= Fold 1 ========
# Our accuracy on the validation set is 0.9811 and AUC is 0.7363
# ======= Fold 2 ========
# Our accuracy on the validation set is 0.9812 and AUC is 0.7581
# ======= Fold 3 ========
# Our accuracy on the validation set is 0.9809 and AUC is 0.7056
# ======= Fold 4 ========
# Our accuracy on the validation set is 0.9809 and AUC is 0.7185
# Our out of fold AUC score is 0.7278
