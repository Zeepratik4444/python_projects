# %% [markdown]
# Welcome,
#
# In This we are using U.S house price prediction dataset to predict the price of houses based on various attributes.
#
# We will analyze the data, clean it, use to visualize and find the corelation with other varribales.
#
# Let's get started by importing nessecary libraries.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %%
df=pd.read_csv('kc_house_data.csv')

# %% [markdown]
# With the help of ADAboost, GradientBoosting, XGBoost, lightBGM, and CATboost we try to predict the prices.

# %% [markdown]
# Importing Dataset

# %% [markdown]
# using head functions to have a glimpse at the data and its constituents.

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %% [markdown]
# Using info method to get a more about the data types and null count.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     21597 non-null  int64
#  9   view           21597 non-null  int64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  int64
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   21597 non-null  int64
#  16  zipcode        21597 non-null  int64
#  17  lat            21597 non-null  float64
#  18  long           21597 non-null  float64
#  19  sqft_living15  21597 non-null  int64
#  20  sqft_lot15     21597 non-null  int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.5+ MB

# %%
df['condition']
# Out:
# 0        3
# 1        3
# 2        3
# 3        5
# 4        3
#         ..
# 21592    3
# 21593    3
# 21594    3
# 21595    3
# 21596    3
# Name: condition, Length: 21597, dtype: int64

# %% [markdown]
# Counting null values in the dataset using isnull

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# Using nunique we get to know the no. of unique values in every columns.

# %%
df.nunique()
# Out:
# id               21420
# date               372
# price             3622
# bedrooms            12
# bathrooms           29
# sqft_living       1034
# sqft_lot          9776
# floors               6
# waterfront           2
# view                 5
# condition            5
# grade               11
# sqft_above         942
# sqft_basement      306
# yr_built           116
# yr_renovated        70
# zipcode             70
# lat               5033
# long               751
# sqft_living15      777
# sqft_lot15        8682
# dtype: int64

# %% [markdown]
# Using Describe to know more about the numerical columns in the dataset.

# %%
df.describe().T
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# yr_built       21597.0  1.971000e+03  2.937523e+01  1.900000e+03
# yr_renovated   21597.0  8.446479e+01  4.018214e+02  0.000000e+00
# zipcode        21597.0  9.807795e+04  5.351307e+01  9.800100e+04
# lat            21597.0  4.756009e+01  1.385518e-01  4.715590e+01
# long           21597.0 -1.222140e+02  1.407235e-01 -1.225190e+02
# sqft_living15  21597.0  1.986620e+03  6.852305e+02  3.990000e+02
# sqft_lot15     21597.0  1.275828e+04  2.727444e+04  6.510000e+02
#
#                         25%           50%           75%           max
# id             2.123049e+09  3.904930e+09  7.308900e+09  9.900000e+09
# price          3.220000e+05  4.500000e+05  6.450000e+05  7.700000e+06
# bedrooms       3.000000e+00  3.000000e+00  4.000000e+00  3.300000e+01
# bathrooms      1.750000e+00  2.250000e+00  2.500000e+00  8.000000e+00
# sqft_living    1.430000e+03  1.910000e+03  2.550000e+03  1.354000e+04
# sqft_lot       5.040000e+03  7.618000e+03  1.068500e+04  1.651359e+06
# floors         1.000000e+00  1.500000e+00  2.000000e+00  3.500000e+00
# waterfront     0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# view           0.000000e+00  0.000000e+00  0.000000e+00  4.000000e+00
# condition      3.000000e+00  3.000000e+00  4.000000e+00  5.000000e+00
# grade          7.000000e+00  7.000000e+00  8.000000e+00  1.300000e+01
# sqft_above     1.190000e+03  1.560000e+03  2.210000e+03  9.410000e+03
# sqft_basement  0.000000e+00  0.000000e+00  5.600000e+02  4.820000e+03
# yr_built       1.951000e+03  1.975000e+03  1.997000e+03  2.015000e+03
# yr_renovated   0.000000e+00  0.000000e+00  0.000000e+00  2.015000e+03
# zipcode        9.803300e+04  9.806500e+04  9.811800e+04  9.819900e+04
# lat            4.747110e+01  4.757180e+01  4.767800e+01  4.777760e+01
# long          -1.223280e+02 -1.222310e+02 -1.221250e+02 -1.213150e+02
# sqft_living15  1.490000e+03  1.840000e+03  2.360000e+03  6.210000e+03
# sqft_lot15     5.100000e+03  7.620000e+03  1.008300e+04  8.712000e+05

# %% [markdown]
# Veiwing the names of the columns using columns method.

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %% [markdown]
# Using shape to know about the dimension of the dataset (Rows, Columns)

# %%
df.shape
# Out:
# (21597, 21)

# %% [markdown]
# Using set Style to set the background style to 'WhiteGrid'.

# %%
sns.set_style('whitegrid')

# %% [markdown]
# Using Corr we are ploting a graph to view the corelation between all the numerical columns.

# %%
sns.heatmap(df.corr(),cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Using Corrwith we can see the correlation with other numerical coumns to a single columns, here we are using price to perform corrwith.

# %%
corr_w=df.corrwith(df['price'])
plt.figure(figsize=(10,6))
corr_w.drop('price').plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Plotting this figure to know the correlation between Sq ft. living area to price as the above graph shows the price is most related to price.

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(x='sqft_living',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='sqft_living', ylabel='price'>

# %% [markdown]
# Using the displot we can check the price distribution of the houses in the datset.

# %%
sns.distplot(df.price,kde=True)
# Out:
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %% [markdown]
# Using countplot to get the data about how many homes are there with diffrent amount of rooms.

# %%
plt.figure(figsize=(8,4))
sns.countplot(x='bedrooms',data=df)
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='count'>

# %% [markdown]
# Using barplot to know whats the mean sq ft living in each category of bedroom no.

# %%
plt.figure(figsize=(8,4))
sns.barplot(x='bedrooms',y='sqft_living',data=df)
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='sqft_living'>

# %% [markdown]
# Using the barplot to check mean price of houses based upon how many floors they have.

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='floors',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='floors', ylabel='price'>

# %% [markdown]
# Checking is their any bedrooms more than 12 to make our data more precise and less mistaken.

# %%
df[df['bedrooms']>12]
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 15856  2402100895  6/25/2014  640000.0        33       1.75         1620
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 15856      6000     1.0           0     0  ...      7        1040
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 15856            580      1947             0    98103  47.6878 -122.331
#
#        sqft_living15  sqft_lot15
# 15856           1330        4700
#
# [1 rows x 21 columns]

# %% [markdown]
# We have seen a house with more than 12 and we are going to remove that house from our dataset.

# %%
df = df.drop(df[df['bedrooms'] > 30].index)

# %% [markdown]
# Using scatterplot to plot a graph between bedrooms and price.

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='bedrooms',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='price'>

# %% [markdown]
# Using scatterlpot to plot the data, houses as location in the graph and their postioning and we have set hue to diffrentiate the pricing.

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='lat',y='long',data=df,hue='price',legend=False)
# Out:
# <AxesSubplot:xlabel='lat', ylabel='long'>

# %% [markdown]
# We are using countplot to compare the quantity of houses with diffrent grades alloted.

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='grade',data=df)
# Out:
# <AxesSubplot:xlabel='grade', ylabel='count'>

# %% [markdown]
# Using scatterplot graph to plot the relation between year the house is built and the price with grade as hue.

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='yr_built',y='price',data=df,hue='grade')
# Out:
# <AxesSubplot:xlabel='yr_built', ylabel='price'>

# %% [markdown]
# Wacthing out for the values and the data types for training our model and eliminating the values which are not usefull

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21596 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21596 non-null  int64
#  1   date           21596 non-null  object
#  2   price          21596 non-null  float64
#  3   bedrooms       21596 non-null  int64
#  4   bathrooms      21596 non-null  float64
#  5   sqft_living    21596 non-null  int64
#  6   sqft_lot       21596 non-null  int64
#  7   floors         21596 non-null  float64
#  8   waterfront     21596 non-null  int64
#  9   view           21596 non-null  int64
#  10  condition      21596 non-null  int64
#  11  grade          21596 non-null  int64
#  12  sqft_above     21596 non-null  int64
#  13  sqft_basement  21596 non-null  int64
#  14  yr_built       21596 non-null  int64
#  15  yr_renovated   21596 non-null  int64
#  16  zipcode        21596 non-null  int64
#  17  lat            21596 non-null  float64
#  18  long           21596 non-null  float64
#  19  sqft_living15  21596 non-null  int64
#  20  sqft_lot15     21596 non-null  int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.6+ MB

# %% [markdown]
# Using value counts for finding the year which which that house was built

# %%
df['yr_built'].value_counts().sort_values(ascending=False)
# Out:
# 2014    559
# 2006    453
# 2005    450
# 2004    433
# 2003    420
#        ...
# 1933     30
# 1901     29
# 1902     27
# 1935     24
# 1934     21
# Name: yr_built, Length: 116, dtype: int64

# %% [markdown]
# Changing the date format to find out the year which it was listed.

# %%
df['date']=pd.to_datetime(df['date'])

# %% [markdown]
# Extracting the year from the date which the the property was listed on.

# %% [raw]
# df['year_listed']=df['date'].dt.year
# df['year_listed']

# %% [markdown]
# Assigning values to x and y varriables to create train test split

# %%
x=df.drop(['date','id','price'],axis=1)
y=df['price']

# %% [markdown]
# Importing train test split from sklearn module

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# Splitting the dataset in Train & Test so that we can test the model with the test data

# %%
x_tr,x_te,y_tr,y_te=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
x_tr.shape
# Out:
# (16197, 18)

# %% [markdown]
# We need to normalize the data in order to fit the model with the help of standard scaler.

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Transforming the training set to normalize and make accurate predictions.

# %%
scaler=StandardScaler()
x_tr=scaler.fit_transform(x_tr)
x_te=scaler.transform(x_te)

# %% [markdown]
# Importing more nessecary libraries

# %%
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import mean_squared_error, r2_score
import math

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# Creating a function to find the best algorithm to work upon the prediction process

# %%
def classify(classification,x_train,y_train,x_test,y_test):
    clf=classification.fit(x_train,y_train)
    pred=clf.predict(x_test)
    print('='*35)
    print(i)
    print('-'*35)
    mse=mean_squared_error(y_test,pred)
    r2=r2_score(y_test,pred)
    print('R2 Score',r2)
    print('Mean Squared Error',mse)
    print('RSME',math.sqrt(mse))
    print('-'*35)
    print('='*35)

# %% [markdown]
# Impoting more libraries and creating a list of algorithms to put in our fucntion.

# %%
from sklearn.ensemble import AdaBoostRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
# Creating a list to store the models
regression_models = [AdaBoostRegressor(),
                     GradientBoostingRegressor(),
                     XGBRegressor(),
                     LGBMRegressor(),
                     LinearRegression(),
                     RandomForestRegressor(),
                     KNeighborsRegressor(),
                     SVR()]

# Print the list of boosting models
print(regression_models)
# Out:
# [AdaBoostRegressor(), GradientBoostingRegressor(), XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...), LGBMRegressor(), LinearRegression(), RandomForestRegressor(), KNeighborsRegressor(), SVR()]

# %% [markdown]
# Checking the algorithms in the classify function to know the accuracy of the result

# %%
for i in regression_models:
  classify(i,x_tr,y_tr,x_te,y_te)
# Out:
# ===================================
# AdaBoostRegressor()
# -----------------------------------
# R2 Score 0.23931050057376724
# Mean Squared Error 105029787375.18134
# RSME 324082.99457882904
# -----------------------------------
# ===================================
# ===================================
# GradientBoostingRegressor()
# -----------------------------------
# R2 Score 0.8679208517160981
# Mean Squared Error 18236409036.034695
# RSME 135042.24907796335
# -----------------------------------
# ===================================
# ===================================
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# -----------------------------------
# R2 Score 0.8844344765801054
# Mean Squared Error 15956342715.192324
# RSME 126318.41795713056
# -----------------------------------
# ===================================
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.010211 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2335
# [LightGBM] [Info] Number of data points in the train set: 16197, number of used features: 18
# [LightGBM] [Info] Start training from score 540984.347719
# ===================================
# LGBMRegressor()
# -----------------------------------
# R2 Score 0.8821976746941017
# Mean Squared Error 16265182033.553598
# RSME 127535.02277238829
# -----------------------------------
# ===================================
# ===================================
# LinearRegression()
# -----------------------------------
# R2 Score 0.6911170317316606
# Mean Squared Error 42648035112.23516
# RSME 206514.0070606233
# -----------------------------------
# ===================================
# ===================================
# RandomForestRegressor()
# -----------------------------------
# R2 Score 0.8762968963257297
# Mean Squared Error 17079913271.260508
# RSME 130690.14221149393
# -----------------------------------
# ===================================
# ===================================
# KNeighborsRegressor()
# -----------------------------------
# R2 Score 0.785666699719117
# Mean Squared Error 29593389908.631264
# RSME 172027.29408041987
# -----------------------------------
# ===================================
# ===================================
# SVR()
# -----------------------------------
# R2 Score -0.05343640514579162
# Mean Squared Error 145449886884.4545
# RSME 381378.9282124204
# -----------------------------------
# ===================================

# %% [markdown]
# As XGBRegressor is showing a good R2 Score so we will be moving forward for the final model.

# %%
reg=XGBRegressor()

# %% [markdown]
# Will be using GridSearchCV to give in parameter settings to get more accuraccy out of the model.

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# We are giving in the parameters and using GridSearchCV to tune the model.

# %%
learning_rate = [0.1, 0.05, 0.01, 0.001]
n_estimators = [100, 500, 1000, 1200, 1500]

hyperparameter_grid = {
    'learning_rate': learning_rate,
    'n_estimators': n_estimators
}

grid_cv = GridSearchCV(
    estimator=reg,
    param_grid=hyperparameter_grid,
    cv=3,
    verbose=3,
    return_train_score=True
)

# %% [markdown]
# And now we will be training the model.

# %%
grid_cv.fit(x_tr,y_tr)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [CV 1/3] END learning_rate=0.1, n_estimators=100;, score=(train=0.964, test=0.859) total time=  10.6s
# [CV 2/3] END learning_rate=0.1, n_estimators=100;, score=(train=0.957, test=0.888) total time=   9.6s
# [CV 3/3] END learning_rate=0.1, n_estimators=100;, score=(train=0.964, test=0.878) total time=   9.3s
# [CV 1/3] END learning_rate=0.1, n_estimators=500;, score=(train=0.990, test=0.862) total time=  47.9s
# [CV 2/3] END learning_rate=0.1, n_estimators=500;, score=(train=0.988, test=0.894) total time=  48.1s
# [CV 3/3] END learning_rate=0.1, n_estimators=500;, score=(train=0.990, test=0.882) total time=  49.0s
# [CV 1/3] END learning_rate=0.1, n_estimators=1000;, score=(train=0.996, test=0.861) total time= 1.6min
# [CV 2/3] END learning_rate=0.1, n_estimators=1000;, score=(train=0.996, test=0.893) total time= 1.8min
# [CV 3/3] END learning_rate=0.1, n_estimators=1000;, score=(train=0.997, test=0.881) total time= 1.5min
# [CV 1/3] END learning_rate=0.1, n_estimators=1200;, score=(train=0.997, test=0.861) total time= 1.9min
# [CV 2/3] END learning_rate=0.1, n_estimators=1200;, score=(train=0.997, test=0.893) total time= 1.8min
# [CV 3/3] END learning_rate=0.1, n_estimators=1200;, score=(train=0.998, test=0.881) total time= 1.9min
# [CV 1/3] END learning_rate=0.1, n_estimators=1500;, score=(train=0.998, test=0.861) total time= 2.3min
# [CV 2/3] END learning_rate=0.1, n_estimators=1500;, score=(train=0.998, test=0.892) total time= 2.2min
# [CV 3/3] END learning_rate=0.1, n_estimators=1500;, score=(train=0.998, test=0.881) total time= 2.3min
# [CV 1/3] END learning_rate=0.05, n_estimators=100;, score=(train=0.946, test=0.862) total time=  10.4s
# [CV 2/3] END learning_rate=0.05, n_estimators=100;, score=(train=0.938, test=0.880) total time=   8.4s
# [CV 3/3] END learning_rate=0.05, n_estimators=100;, score=(train=0.948, test=0.869) total time=  10.1s
# [CV 1/3] END learning_rate=0.05, n_estimators=500;, score=(train=0.980, test=0.875) total time=  46.9s
# [CV 2/3] END learning_rate=0.05, n_estimators=500;, score=(train=0.977, test=0.893) total time=  47.6s
# [CV 3/3] END learning_rate=0.05, n_estimators=500;, score=(train=0.981, test=0.885) total time=  46.7s
# [CV 1/3] END learning_rate=0.05, n_estimators=1000;, score=(train=0.990, test=0.875) total time= 1.5min
# [CV 2/3] END learning_rate=0.05, n_estimators=1000;, score=(train=0.989, test=0.893) total time= 1.5min
# [CV 3/3] END learning_rate=0.05, n_estimators=1000;, score=(train=0.990, test=0.886) total time= 1.5min
# [CV 1/3] END learning_rate=0.05, n_estimators=1200;, score=(train=0.992, test=0.875) total time= 2.0min
# [CV 2/3] END learning_rate=0.05, n_estimators=1200;, score=(train=0.991, test=0.893) total time= 2.0min
# [CV 3/3] END learning_rate=0.05, n_estimators=1200;, score=(train=0.992, test=0.886) total time= 1.9min
# [CV 1/3] END learning_rate=0.05, n_estimators=1500;, score=(train=0.994, test=0.875) total time= 2.4min
# [CV 2/3] END learning_rate=0.05, n_estimators=1500;, score=(train=0.993, test=0.893) total time= 2.3min
# [CV 3/3] END learning_rate=0.05, n_estimators=1500;, score=(train=0.994, test=0.886) total time= 2.2min
# [CV 1/3] END learning_rate=0.01, n_estimators=100;, score=(train=0.431, test=0.377) total time=  10.0s
# [CV 2/3] END learning_rate=0.01, n_estimators=100;, score=(train=0.411, test=0.406) total time=   9.3s
# [CV 3/3] END learning_rate=0.01, n_estimators=100;, score=(train=0.452, test=0.339) total time=   9.1s
# [CV 1/3] END learning_rate=0.01, n_estimators=500;, score=(train=0.947, test=0.862) total time=  47.7s
# [CV 2/3] END learning_rate=0.01, n_estimators=500;, score=(train=0.938, test=0.878) total time=  46.4s
# [CV 3/3] END learning_rate=0.01, n_estimators=500;, score=(train=0.947, test=0.867) total time=  48.1s
# [CV 1/3] END learning_rate=0.01, n_estimators=1000;, score=(train=0.963, test=0.870) total time= 1.6min
# [CV 2/3] END learning_rate=0.01, n_estimators=1000;, score=(train=0.957, test=0.887) total time= 1.6min
# [CV 3/3] END learning_rate=0.01, n_estimators=1000;, score=(train=0.964, test=0.880) total time= 1.6min
# [CV 1/3] END learning_rate=0.01, n_estimators=1200;, score=(train=0.967, test=0.871) total time= 1.9min
# [CV 2/3] END learning_rate=0.01, n_estimators=1200;, score=(train=0.961, test=0.889) total time= 1.9min
# [CV 3/3] END learning_rate=0.01, n_estimators=1200;, score=(train=0.967, test=0.882) total time= 1.9min
# [CV 1/3] END learning_rate=0.01, n_estimators=1500;, score=(train=0.971, test=0.873) total time= 2.3min
# [CV 2/3] END learning_rate=0.01, n_estimators=1500;, score=(train=0.967, test=0.891) total time= 2.3min
# [CV 3/3] END learning_rate=0.01, n_estimators=1500;, score=(train=0.971, test=0.883) total time= 2.3min
# [CV 1/3] END learning_rate=0.001, n_estimators=100;, score=(train=-1.663, test=-1.642) total time=   8.8s
# [CV 2/3] END learning_rate=0.001, n_estimators=100;, score=(train=-1.741, test=-1.505) total time=  10.4s
# [CV 3/3] END learning_rate=0.001, n_estimators=100;, score=(train=-1.560, test=-1.881) total time=   8.0s
# [CV 1/3] END learning_rate=0.001, n_estimators=500;, score=(train=-0.307, test=-0.338) total time=  46.1s
# [CV 2/3] END learning_rate=0.001, n_estimators=500;, score=(train=-0.347, test=-0.270) total time=  48.2s
# [CV 3/3] END learning_rate=0.001, n_estimators=500;, score=(train=-0.257, test=-0.438) total time=  50.0s
# [CV 1/3] END learning_rate=0.001, n_estimators=1000;, score=(train=0.427, test=0.373) total time= 1.5min
# [CV 2/3] END learning_rate=0.001, n_estimators=1000;, score=(train=0.407, test=0.402) total time= 1.1min
# [CV 3/3] END learning_rate=0.001, n_estimators=1000;, score=(train=0.448, test=0.335) total time= 1.1min
# [CV 1/3] END learning_rate=0.001, n_estimators=1200;, score=(train=0.576, test=0.517) total time= 1.3min
# [CV 2/3] END learning_rate=0.001, n_estimators=1200;, score=(train=0.560, test=0.539) total time= 1.3min
# [CV 3/3] END learning_rate=0.001, n_estimators=1200;, score=(train=0.592, test=0.490) total time= 1.3min
# [CV 1/3] END learning_rate=0.001, n_estimators=1500;, score=(train=0.719, test=0.654) total time= 1.6min
# [CV 2/3] END learning_rate=0.001, n_estimators=1500;, score=(train=0.706, test=0.671) total time= 1.6min
# [CV 3/3] END learning_rate=0.001, n_estimators=1500;, score=(train=0.730, test=0.639) total time= 1.6min
# GridSearchCV(cv=3,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None, gpu_id=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     max_cat_threshold=None,
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None, n_estimators=100,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     predictor=None, random_state=None, ...),
#              param_grid={'learning_rate': [0.1, 0.05, 0.01, 0.001],
#                          'n_estimators': [100, 500, 1000, 1200, 1500]},
#              return_train_score=True, verbose=3)

# %% [markdown]
# Using Best_estimators_ to find the best parameter settings for tuning the model.

# %%
best_params = grid_cv.best_estimator_

# %% [markdown]
# Putting the parameters we found from best_estimators_ to work in the XGBregressor model.

# %%
reg_n = XGBRegressor(learning_rate=best_params.learning_rate,
                                 n_estimators=best_params.n_estimators)

# %% [markdown]
# Fitting the model from new regression model.

# %%
reg_n.fit(x_tr,y_tr)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=1000, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %% [markdown]
# Predicting based upon the new model.

# %%
pred=reg_n.predict(x_te)

# %% [markdown]
# Checking the scores of the predicted results from the new model we devloped.

# %%
print('R2 Score :',r2_score(y_te,pred))
print('\n')
print('MSE :',mean_squared_error(y_te,pred))
print('\n')
print('RSME :',math.sqrt(mean_squared_error(y_te,pred)))
# Out:
# R2 Score : 0.8892465748610512
#
#
# MSE : 15291927523.898859
#
#
# RSME : 123660.53341264083
